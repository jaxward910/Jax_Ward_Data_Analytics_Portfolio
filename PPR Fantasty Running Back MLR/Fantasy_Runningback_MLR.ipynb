# %% [markdown]
# # Multiple Linear Regression for RB PPR Fantasy Football Production

# %%
library(tidyverse)
library(nflfastR)
library(broom)
library(kableExtra)
library(nflreadr)
library(nflplotR)

# %%
ps <- load_player_stats(2021:2024)

# %%
ps_fantasy <- ps |>
    group_by(player_id, season) |>
    filter(season_type != "POST") |>
    mutate(season_fantasy_points_ppr = sum(fantasy_points_ppr, na.rm = TRUE)) |>
    ungroup()

# %%
ps_fantasy <- ps_fantasy |>
    mutate(fantasy_points_ppr_pergame = season_fantasy_points_ppr / 17)

# %%
ps_fantasy |>
    rename(player = player_display_name)
# Out:
#       player_id  player_name      player             position position_group
# 1     00-0019596 T.Brady          Tom Brady          QB       QB
# 2     00-0022824 A.Lee            Andy Lee           P        SPEC
# 3     00-0022924 B.Roethlisberger Ben Roethlisberger QB       QB
# 4     00-0023252 R.Gould          Robbie Gould       K        SPEC
# 5     00-0023459 Aa.Rodgers       Aaron Rodgers      QB       QB
# 6     00-0023682 R.Fitzpatrick    Ryan Fitzpatrick   QB       QB
# 7     00-0023853 M.Prater         Matt Prater        K        SPEC
# 8     00-0024243 M.Lewis          Marcedes Lewis     TE       TE
# 9     00-0024417 S.Koch           Sam Koch           P        SPEC
# 10    00-0025565 N.Folk           Nick Folk          K        SPEC
# 11    00-0025580 M.Crosby         Mason Crosby       K        SPEC
# 12    00-0025825 B.Kern           Brett Kern         P        SPEC
# 13    00-0026027 J.Jansen         J.J. Jansen        LS       SPEC
# 14    00-0026035 D.Amendola       Danny Amendola     WR       WR
# 15    00-0026143 M.Ryan           Matt Ryan          QB       QB
# 16    00-0026189 D.Jackson        DeSean Jackson     WR       WR
# 17    00-0026190 C.Campbell       Calais Campbell    DE       DL
# 18    00-0026498 M.Stafford       Matthew Stafford   QB       QB
# 19    00-0026564 S.McLendon       Steve McLendon     NT       DL
# 20    00-0026858 G.Gano           Graham Gano        K        SPEC
# 21    00-0026968 R.Succop         Ryan Succop        K        SPEC
# 22    00-0026990 M.Jenkins        Malcolm Jenkins    S        DB
# 23    00-0027061 J.Cook           Jared Cook         TE       TE
# 24    00-0027103 K.Huber          Kevin Huber        P        SPEC
# 25    00-0027136 J.McCourty       Jason McCourty     S        DB
# 26    00-0027224 J.Weeks          Jon Weeks          LS       SPEC
# 27    00-0027539 A.Levine         Anthony Levine     DB       DB
# 28    00-0027647 D.McCourty       Devin McCourty     FS       DB
# 29    00-0027656 R.Gronkowski     Rob Gronkowski     TE       TE
# 30    00-0027662 C.Dunlap         Carlos Dunlap      DE       DL
# ⋮     ⋮          ⋮                ⋮                  ⋮        ⋮
# 72014 00-0039872 C.Bishop         Cole Bishop        SAF      DB
# 72015 00-0039873 D.Carter         DeWayne Carter     DT       DL
# 72016 00-0039874 J.Wright         Jaylen Wright      RB       RB
# 72017 00-0039875 R.Davis          Ray Davis          RB       RB
# 72018 00-0039878 E.Ulofoshio      Edefuan Ulofoshio  LB       LB
# 72019 00-0039879 J.Solomon        Javon Solomon      DE       DL
# 72020 00-0039880 M.Washington     Malik Washington   WR       WR
# 72021 00-0039882 T.Grable         Tylan Grable       OT       OL
# 72022 00-0039886 T.Sweat          T'Vondre Sweat     DT       DL
# 72023 00-0039887 L.Robinson       Layden Robinson    G        OL
# 72024 00-0039889 M.Smith          Maason Smith       DT       DL
# 72025 00-0039890 A.Mitchell       Adonai Mitchell    WR       WR
# 72026 00-0039893 B.Thomas         Brian Thomas Jr.   WR       WR
# 72027 00-0039895 M.Hall           Mike Hall Jr.      DT       DL
# 72028 00-0039897 J.Alt            Joe Alt            OT       OL
# 72029 00-0039898 M.Sainristil     Mike Sainristil    CB       DB
# 72030 00-0039899 P.Paul           Patrick Paul       OT       OL
# 72031 00-0039901 K.Coleman        Keon Coleman       WR       WR
# 72032 00-0039903 T.Arnold         Terrion Arnold     CB       DB
# 72033 00-0039906 J.Newton         Jer'Zhan Newton    DT       DL
# 72034 00-0039908 K.Jenkins        Kris Jenkins       DT       DL
# 72035 00-0039910 J.Daniels        Jayden Daniels     QB       QB
# 72036 00-0039911 C.Robinson       Chop Robinson      LB       LB
# 72037 00-0039915 L.McConkey       Ladd McConkey      WR       WR
# 72038 00-0039916 R.Pearsall       Ricky Pearsall     WR       WR
# 72039 00-0039917 M.Penix          Michael Penix Jr.  QB       QB
# 72040 00-0039918 C.Williams       Caleb Williams     QB       QB
# 72041 00-0039919 R.Odunze         Rome Odunze        WR       WR
# 72042 00-0039924 D.Turner         Dallas Turner      LB       LB
# 72043 NA         NA               NA                 NA       NA
#       headshot_url
# 1     https://static.www.nfl.com/image/private/f_auto,q_auto/league/q7dpdlxyu5rs05rgh1le
# 2     https://static.www.nfl.com/image/private/f_auto,q_auto/league/bfozbs2h9jueavslvw3z
# 3     https://static.www.nfl.com/image/private/f_auto,q_auto/league/vziogpnyp9d0xtpiuqhr
# 4     https://static.www.nfl.com/image/private/f_auto,q_auto/league/uakpiwhnutg2rvoyrmgh
# 5     https://static.www.nfl.com/image/upload/f_auto,q_auto/league/dypvakakxhccxs67tb0y
# 6     https://static.www.nfl.com/image/private/f_auto,q_auto/league/pkhhxwplsawnhln9rsun
# 7     https://static.www.nfl.com/image/upload/f_auto,q_auto/league/mwlrdghrm5chsum2kzic
# 8     https://static.www.nfl.com/image/private/f_auto,q_auto/league/ppq07tipygpftz5csipx
# 9     https://static.www.nfl.com/image/private/f_auto,q_auto/league/dw34lcf6qit1i1knjhpv
# 10    https://static.www.nfl.com/image/upload/f_auto,q_auto/league/qcfiv2cc7ky37yq9iklp
# 11    https://static.www.nfl.com/image/private/f_auto,q_auto/league/usbwgcjsdcugjafgjzvt
# 12    https://static.www.nfl.com/image/private/f_auto,q_auto/league/dbph1kuozunx3aorpeiw
# 13    https://static.www.nfl.com/image/upload/f_auto,q_auto/league/vmbidsuvur7zfmpt9xak
# 14    https://static.www.nfl.com/image/private/f_auto,q_auto/league/etz06w7s0ardf49mnayz
# 72026 284.00                    16.705882
# 72027   0.00                     0.000000
# 72028   0.00                     0.000000
# 72029   0.00                     0.000000
# 72030   0.00                     0.000000
# 72031 111.50                     6.558824
# 72032   0.00                     0.000000
# 72033   0.00                     0.000000
# 72034   0.00                     0.000000
# 72035 355.82                    20.930588
# 72036   0.00                     0.000000
# 72037 240.90                    14.170588
# 72038  93.50                     5.500000
# 72039  44.10                     2.594118
# 72040 254.54                    14.972941
# 72041 144.90                     8.523529
# 72042   0.00                     0.000000
# 72043   0.00                     0.000000

# %% [markdown]
# # Consistency Analysis

# %%
ps_fantasy |>
    filter(position == "RB") |>
    select(fantasy_points_ppr_pergame, carries,
     rushing_yards, rushing_tds, rushing_first_downs,
     rushing_epa, receptions, targets, receiving_yards,
     receiving_tds, receiving_epa) |>
    cor(use = 'complete.obs' )
# Out:
#                            fantasy_points_ppr_pergame carries
# fantasy_points_ppr_pergame 1.00000000                  0.575560280
# carries                    0.57556028                  1.000000000
# rushing_yards              0.52235200                  0.848568884
# rushing_tds                0.31763655                  0.432875579
# rushing_first_downs        0.47743866                  0.789991006
# rushing_epa                0.03735837                 -0.002949105
# receptions                 0.36015728                  0.197210044
# targets                    0.37065389                  0.200033159
# receiving_yards            0.29500094                  0.161393012
# receiving_tds              0.15446698                  0.068751164
# receiving_epa              0.07211651                  0.063707780
#                            rushing_yards rushing_tds rushing_first_downs
# fantasy_points_ppr_pergame 0.52235200    0.31763655  0.47743866
# carries                    0.84856888    0.43287558  0.78999101
# rushing_yards              1.00000000    0.47260288  0.84829871
# rushing_tds                0.47260288    1.00000000  0.54910516
# rushing_first_downs        0.84829871    0.54910516  1.00000000
# rushing_epa                0.38537775    0.37027514  0.39296327
# receptions                 0.14065062    0.07548555  0.15066079
# targets                    0.13541204    0.07089074  0.13927469
# receiving_yards            0.11367352    0.10179794  0.11945755
# receiving_tds              0.08180177    0.01720764  0.06939966
# receiving_epa              0.05588490    0.07013165  0.05706956
#                            rushing_epa  receptions  targets     receiving_yards
# fantasy_points_ppr_pergame  0.037358371  0.36015728  0.37065389  0.29500094
# carries                    -0.002949105  0.19721004  0.20003316  0.16139301
# rushing_yards               0.385377746  0.14065062  0.13541204  0.11367352
# rushing_tds                 0.370275144  0.07548555  0.07089074  0.10179794
# rushing_first_downs         0.392963275  0.15066079  0.13927469  0.11945755
# rushing_epa                 1.000000000 -0.04300471 -0.06677848 -0.02774609
# receptions                 -0.043004712  1.00000000  0.91132658  0.74638395
# targets                    -0.066778477  0.91132658  1.00000000  0.67735435
# receiving_yards            -0.027746086  0.74638395  0.67735435  1.00000000
# receiving_tds               0.029158272  0.24275876  0.20171407  0.32894568
# receiving_epa               0.007170531  0.21293693  0.03931147  0.57243439
#                            receiving_tds receiving_epa
# fantasy_points_ppr_pergame 0.15446698    0.072116514
# carries                    0.06875116    0.063707780
# rushing_yards              0.08180177    0.055884896
# rushing_tds                0.01720764    0.070131648
# rushing_first_downs        0.06939966    0.057069563
# rushing_epa                0.02915827    0.007170531
# receptions                 0.24275876    0.212936929
# targets                    0.20171407    0.039311472
# receiving_yards            0.32894568    0.572434394
# receiving_tds              1.00000000    0.392158434
# receiving_epa              0.39215843    1.000000000

# %% [markdown]
# Carries (0.58) → Moderate positive correlation. More carries generally = more PPR points.
#
# Rushing yards (0.52) → Moderate positive correlation, makes sense since rushing yards directly add to fantasy points.
#
# Rushing TDs (0.32) → Weaker but positive correlation (TDs are valuable but less consistent week-to-week).
#
# Rushing first downs (0.48) → Similar to rushing yards, moderate correlation. Indicates steady usage is tied to fantasy output.
#
# Rushing EPA (0.04) → Very weak correlation. Efficiency doesn’t matter much compared to pure volume for fantasy scoring.
#
# Receptions (0.36) → Moderate positive correlation. In PPR scoring, catches add direct value.
#
# Targets (0.37) → Similar to receptions, logical since targets = opportunities.
#
# Receiving yards (0.30) → Weaker but positive correlation.
#
# Receiving TDs (0.15) → Very weak correlation—receiving TDs are rare events, so not strongly predictive per game.
#
# Receiving EPA (0.07) → Almost no correlation, again showing efficiency isn’t what drives fantasy points.
#
# Takeaway: Volume > Efficiency Fantasy scoring in PPR is much more volume-driven (carries, yards, receptions, targets) than efficiency-driven (EPA). Touchdowns matter, but not as consistently per game as volume stats.

# %% [markdown]
# # Season Performance Analysis

# %%
ps_fantasy |>
    filter(position == "RB") |>
    select(season_fantasy_points_ppr, carries,
     rushing_yards, rushing_tds, rushing_first_downs,
     rushing_epa, receptions, targets, receiving_yards,
     receiving_tds, receiving_epa) |>
    cor(use = 'complete.obs' )
# Out:
#                           season_fantasy_points_ppr carries      rushing_yards
# season_fantasy_points_ppr 1.00000000                 0.575560280 0.52235200
# carries                   0.57556028                 1.000000000 0.84856888
# rushing_yards             0.52235200                 0.848568884 1.00000000
# rushing_tds               0.31763655                 0.432875579 0.47260288
# rushing_first_downs       0.47743866                 0.789991006 0.84829871
# rushing_epa               0.03735837                -0.002949105 0.38537775
# receptions                0.36015728                 0.197210044 0.14065062
# targets                   0.37065389                 0.200033159 0.13541204
# receiving_yards           0.29500094                 0.161393012 0.11367352
# receiving_tds             0.15446698                 0.068751164 0.08180177
# receiving_epa             0.07211651                 0.063707780 0.05588490
#                           rushing_tds rushing_first_downs rushing_epa
# season_fantasy_points_ppr 0.31763655  0.47743866           0.037358371
# carries                   0.43287558  0.78999101          -0.002949105
# rushing_yards             0.47260288  0.84829871           0.385377746
# rushing_tds               1.00000000  0.54910516           0.370275144
# rushing_first_downs       0.54910516  1.00000000           0.392963275
# rushing_epa               0.37027514  0.39296327           1.000000000
# receptions                0.07548555  0.15066079          -0.043004712
# targets                   0.07089074  0.13927469          -0.066778477
# receiving_yards           0.10179794  0.11945755          -0.027746086
# receiving_tds             0.01720764  0.06939966           0.029158272
# receiving_epa             0.07013165  0.05706956           0.007170531
#                           receptions  targets     receiving_yards receiving_tds
# season_fantasy_points_ppr  0.36015728  0.37065389  0.29500094     0.15446698
# carries                    0.19721004  0.20003316  0.16139301     0.06875116
# rushing_yards              0.14065062  0.13541204  0.11367352     0.08180177
# rushing_tds                0.07548555  0.07089074  0.10179794     0.01720764
# rushing_first_downs        0.15066079  0.13927469  0.11945755     0.06939966
# rushing_epa               -0.04300471 -0.06677848 -0.02774609     0.02915827
# receptions                 1.00000000  0.91132658  0.74638395     0.24275876
# targets                    0.91132658  1.00000000  0.67735435     0.20171407
# receiving_yards            0.74638395  0.67735435  1.00000000     0.32894568
# receiving_tds              0.24275876  0.20171407  0.32894568     1.00000000
# receiving_epa              0.21293693  0.03931147  0.57243439     0.39215843
#                           receiving_epa
# season_fantasy_points_ppr 0.072116514
# carries                   0.063707780
# rushing_yards             0.055884896
# rushing_tds               0.070131648
# rushing_first_downs       0.057069563
# rushing_epa               0.007170531
# receptions                0.212936929
# targets                   0.039311472
# receiving_yards           0.572434394
# receiving_tds             0.392158434
# receiving_epa             1.000000000

# %% [markdown]
# Carries (0.57) – Strongest correlation → more carries = more total fantasy points across a season.
#
# Rushing yards (0.52) – Strong link, yards accumulate over time.
#
# Rushing first downs (0.47) – Usage indicator, strong correlation with season fantasy output.
#
# Targets (0.37) – Passing-game opportunity strongly tied to season fantasy totals.
#
# Receptions (0.36) – Direct scoring in PPR.
#
# Rushing TDs (0.32) – Contributes, but less consistent across a season than volume.
#
# Receiving yards (0.30) – Positive correlation, but weaker than rushing yards.
#
# Receiving TDs (0.15) – Touchdowns are helpful but volatile over a season.
#
# Receiving EPA (0.07) – Almost no correlation.
#
# Rushing EPA (0.04) – Basically irrelevant for fantasy points.
#
# Almost Identical to per game metrics

# %% [markdown]
# # EDA Plots

# %%
ps_fantasy |>
    filter(position == "RB") |> 
    ggplot(aes(x = fantasy_points_ppr_pergame, y = carries)) +
    geom_point() +
    theme_bw()
# Out:
# plot without title

# %%
sc <- load_snap_counts(2021:2024)

# %%
sc <- sc |>
    group_by(player, season) |>
    filter(game_type != "POST") |>
    mutate(season_snaps = sum(offense_snaps, na.rm = TRUE)) |>
    ungroup()

# %%
ps_fantasy_rbs <- ps_fantasy |>
    filter(position == "RB")

# %%
# Merge sc and ps_fantasy by player and season
merged_df <- sc |>
    select(player, season, season_snaps) |>
    inner_join(ps_fantasy_rbs |> select(player_display_name, season, fantasy_points_ppr_pergame, carries, targets, rushing_tds, receiving_tds),
               by = c("player" = "player_display_name", "season" = "season"))

# Scatter plot: season_snaps vs fantasy_points_ppr_pergame
merged_df |>
    ggplot(aes(x = season_snaps, y = fantasy_points_ppr_pergame)) +
    geom_point(alpha = 0.6) +
    labs(x = "Season Snaps", y = "Fantasy Points PPR Per Game") +
    theme_bw()
# Out:
# Warning message in inner_join(select(sc, player, season, season_snaps), select(ps_fantasy_rbs, :
# "Detected an unexpected many-to-many relationship between `x` and `y`.
# ℹ Row 9 of `x` matches multiple rows in `y`.
# ℹ Row 31 of `y` matches multiple rows in `x`.
# ℹ If a many-to-many relationship is expected, set `relationship =
#   "many-to-many"` to silence this warning."
# plot without title

# %% [markdown]
# # Model Creation

# %%
expected_fpoints_model <- lm(
fantasy_points_ppr_pergame ~ 
 1 + carries + rushing_yards + rushing_tds + rushing_first_downs + 
 receptions + targets + receiving_yards + receiving_tds,
 data = ps_fantasy_rbs)

# %%
print(summary(expected_fpoints_model))
# Out:
# Call:
# lm(formula = fantasy_points_ppr_pergame ~ 1 + carries + rushing_yards +
#     rushing_tds + rushing_first_downs + receptions + targets +
#     receiving_yards + receiving_tds, data = ps_fantasy_rbs)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -13.1299  -2.1624  -0.5276   2.1061  15.4189
#
# Coefficients:
#                      Estimate Std. Error t value Pr(>|t|)
# (Intercept)          1.794750   0.073360  24.465  < 2e-16 ***
# carries              0.334785   0.014861  22.528  < 2e-16 ***
# rushing_yards        0.021007   0.003261   6.443 1.26e-10 ***
# rushing_tds          0.835251   0.109580   7.622 2.87e-14 ***
# rushing_first_downs -0.119291   0.051146  -2.332   0.0197 *
# receptions           0.127834   0.082099   1.557   0.1195
# targets              0.583013   0.061919   9.416  < 2e-16 ***
# receiving_yards      0.005747   0.004766   1.206   0.2279
# receiving_tds        0.963364   0.193398   4.981 6.49e-07 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 3.603 on 6100 degrees of freedom
# Multiple R-squared:  0.5519,	Adjusted R-squared:  0.5513
# F-statistic: 939.2 on 8 and 6100 DF,  p-value: < 2.2e-16

# %% [markdown]
# R² = 0.55 → About 55% of the variation in fantasy points per game is explained by these variables. That’s reasonably strong for sports performance, where variance is high.
#
# Adjusted R² ≈ 0.55 → Similar to R², so the predictors included are genuinely useful, not just padding.
#
#  p < 2.2e-16 → The overall model is highly significant.

# %%
install.packages("car")
# Out:
# Warning message:
# "package 'car' is in use and will not be installed"

# %%
library("car")

# %%
vif_values <- vif(expected_fpoints_model)

# %%
print(vif_values)
# Out:
#             carries       rushing_yards         rushing_tds rushing_first_downs
#            5.137909            6.446821            1.516220            5.154514
#          receptions             targets     receiving_yards       receiving_tds
#           10.798600            8.936512            3.071500            1.153615

# %% [markdown]
# Multicollinearity is clearly at play:
#
# Receptions vs. Targets (highly correlated).
#
# Rushing yards vs. Carries.
#
# Rushing first downs overlaps with both carries and yards

# %% [markdown]
# Creating a new model removing receptions, rushing yards, recieving yards, and rushing first downs

# %%
model2 <- lm(
fantasy_points_ppr_pergame ~ 
 1 + carries + rushing_tds + targets + receiving_tds,
 data = ps_fantasy_rbs)

# %%
print(summary(model2))
# Out:
# Call:
# lm(formula = fantasy_points_ppr_pergame ~ 1 + carries + rushing_tds +
#     targets + receiving_tds, data = ps_fantasy_rbs)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -13.537  -2.165  -0.532   2.137  15.467
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)   1.780234   0.073561  24.201  < 2e-16 ***
# carries       0.399758   0.008001  49.963  < 2e-16 ***
# rushing_tds   0.902138   0.101898   8.853  < 2e-16 ***
# targets       0.701810   0.023033  30.470  < 2e-16 ***
# receiving_tds 1.137846   0.186788   6.092 1.19e-09 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 3.617 on 6104 degrees of freedom
# Multiple R-squared:  0.5483,	Adjusted R-squared:  0.548
# F-statistic:  1853 on 4 and 6104 DF,  p-value: < 2.2e-16

# %% [markdown]
# R² = 0.54 vs. 0.54 before →  lost less than 1% of explanatory power while cutting half the predictors.
#
# Adjusted R² = 0.54 → Strong, and essentially the same as before.
#
# Carries and targets are the two dominant “volume” metrics for predicting RB fantasy scoring.
#
# Touchdowns matter, but in regression terms they do not fully show the raw 6 points because their effect is partly absorbed by volume stats.
#
# Simplified model ≈ same R² as the full model → suggests the dropped variables were redundant.
#
# Higher F Statistic → the simplified model is more statistically significant overall.

# %%
model3 <- lm(
fantasy_points_ppr_pergame ~ 
 1 + carries + rushing_tds + targets + receiving_tds + season_snaps,
 data = merged_df)

# %%
print(summary(model3))
# Out:
# Call:
# lm(formula = fantasy_points_ppr_pergame ~ 1 + carries + rushing_tds +
#     targets + receiving_tds + season_snaps, data = merged_df)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -17.5109  -1.1536  -0.0973   0.8733   8.6778
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)   -7.504e-01  1.247e-02  -60.16   <2e-16 ***
# carries        7.515e-02  1.335e-03   56.28   <2e-16 ***
# rushing_tds    7.085e-01  1.415e-02   50.07   <2e-16 ***
# targets        1.019e-01  3.457e-03   29.46   <2e-16 ***
# receiving_tds  6.582e-01  2.550e-02   25.82   <2e-16 ***
# season_snaps   1.785e-02  3.833e-05  465.71   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1.947 on 86869 degrees of freedom
# Multiple R-squared:  0.8734,	Adjusted R-squared:  0.8734
# F-statistic: 1.199e+05 on 5 and 86869 DF,  p-value: < 2.2e-16

# %% [markdown]
# Model 3 with included snap counts
# .32 increase in R squared and huge increase in F statistic.

# %%
merged_df
# Out:
#       player           season season_snaps fantasy_points_ppr_pergame carries
# 1     Derrick Henry    2021   441          11.37058824                17
# 2     Derrick Henry    2021   441          11.37058824                35
# 3     Derrick Henry    2021   441          11.37058824                28
# 4     Derrick Henry    2021   441          11.37058824                33
# 5     Derrick Henry    2021   441          11.37058824                29
# 6     Derrick Henry    2021   441          11.37058824                20
# 7     Derrick Henry    2021   441          11.37058824                29
# 8     Derrick Henry    2021   441          11.37058824                28
# 9     Jeremy McNichols 2021   269           4.32941176                 2
# 10    Jeremy McNichols 2021   269           4.32941176                 1
# 11    Jeremy McNichols 2021   269           4.32941176                 2
# 12    Jeremy McNichols 2021   269           4.32941176                 1
# 13    Jeremy McNichols 2021   269           4.32941176                 1
# 14    Jeremy McNichols 2021   269           4.32941176                 0
# 15    Jeremy McNichols 2021   269           4.32941176                 0
# 16    Jeremy McNichols 2021   269           4.32941176                 7
# 17    Jeremy McNichols 2021   269           4.32941176                 4
# 18    Jeremy McNichols 2021   269           4.32941176                 8
# 19    Jeremy McNichols 2021   269           4.32941176                 6
# 20    Jeremy McNichols 2021   269           4.32941176                 7
# 21    Jeremy McNichols 2021   269           4.32941176                 2
# 22    Mekhi Sargent    2021     6           0.06470588                 1
# 23    Mekhi Sargent    2021     6           0.06470588                 1
# 86860  2      0           0
# 86861  3      1           0
# 86862  0      1           0
# 86863  0      0           0
# 86864  0      0           0
# 86865  2      0           0
# 86866  3      0           0
# 86867  0      0           0
# 86868  0      0           0
# 86869  1      0           0
# 86870  0      0           0
# 86871  0      0           0
# 86872  1      0           0
# 86873  2      0           0
# 86874  0      0           0
# 86875  2      0           0

# %%
residuals <- model3$residuals

merged_df <- merged_df |>
    mutate(expected_fantasy_points_per_game = merged_df$fantasy_points_ppr_pergame + residuals)

# %%
filter(merged_df, season == 2024) |>
    select(player, season, fantasy_points_ppr_pergame, expected_fantasy_points_per_game) |>
    distinct(player, .keep_all = TRUE) |>
    arrange(desc(expected_fantasy_points_per_game)) |>
    print()
# Out:
# # A tibble: 144 × 4
#    player         season fantasy_points_ppr_pergame expected_fantasy_points_pe…¹
#    <chr>           <int>                      <dbl>                        <dbl>
#  1 Jahmyr Gibbs     2024                       21.3                         29.0
#  2 Derrick Henry    2024                       19.8                         25.7
#  3 Bijan Robinson   2024                       20.1                         23.7
#  4 De'Von Achane    2024                       17.6                         21.3
#  5 Josh Jacobs      2024                       17.2                         20.9
#  6 Saquon Barkley   2024                       20.9                         20.3
#  7 James Cook       2024                       15.7                         20.0
#  8 Bucky Irving     2024                       14.4                         18.7
#  9 Alvin Kamara     2024                       15.6                         18.2
# 10 Chase Brown      2024                       15                           18.0
# # ℹ 134 more rows
# # ℹ abbreviated name: ¹​expected_fantasy_points_per_game

# %%
currentrbs <- load_player_stats(2025)

# %%
 currentrbs |>
    mutate(season_fantasy_points_ppr = sum(fantasy_points_ppr, na.rm = TRUE)) |>
    mutate(fantasy_points_ppr_pergame = season_fantasy_points_ppr / 5) |>
    mutate(volume = carries + targets) |>
    mutate(totalTDs = rushing_tds + receiving_tds) |>
    filter(position == "RB") |>
    select(week, player_display_name, volume, totalTDs) |>
    arrange(desc(volume)) |>
    print( n = 20)
# Out:
# ── nflverse player stats: week level ───────────────────────────────────────────
#
# ℹ Data updated: 2025-10-07 04:30:19 CDT
# # A tibble: 458 × 4
#     week player_display_name volume totalTDs
#    <int> <chr>                <int>    <int>
#  1     1 Christian McCaffrey     32        0
#  2     3 Christian McCaffrey     32        0
#  3     5 Christian McCaffrey     31        1
#  4     3 Bucky Irving            29        0
#  5     3 Jahmyr Gibbs            28        2
#  6     4 Christian McCaffrey     28        1
#  7     2 Alvin Kamara            27        0
#  8     2 Jonathan Taylor         27        1
#  9     2 Bijan Robinson          27        0
# 10     4 Cam Skattebo            27        0
# 11     5 Rico Dowdle             27        1
# 12     3 Omarion Hampton         26        1
# 13     4 Josh Jacobs             26        2
# 14     4 James Cook              26        1
# 15     2 Javonte Williams        25        1
# 16     3 Josh Jacobs             25        0
# 17     4 Kenneth Gainwell        25        2
# 18     4 Quinshon Judkins        25        1
# 19     5 Quinshon Judkins        25        0
# 20     1 Chase Brown             24        1
# # ℹ 438 more rows

# %%
library("ggrepel")

# %%
currentrbs |>
    filter(position == "RB") |>
    mutate(volume = carries + targets) |>
    group_by(player_display_name) |>
    summarise(
        volume = sum(volume, na.rm = TRUE),
        fantasy_points_ppr_pergame = sum(fantasy_points_ppr, na.rm = TRUE) / 5
    ) |>
    arrange(desc(volume)) |>
    slice_head(n = 32) |>
    ggplot(aes(x = reorder(player_display_name, volume), y = volume)) +
    geom_bar(stat = "identity", fill = "firebrick1") +
    geom_text(aes(label = round(fantasy_points_ppr_pergame, 1)), hjust = -0.1, size = 3) +
    coord_flip() +
    labs(
     x = "Player",
     y = "Volume (Carries + Targets)",
     caption = "Creator: Jax Ward Data: @nflfastR",
     subtitle = "Data labels show PPR fantasy points per game",
     title = "Top 32 RBs by Volume (2025)") +
    theme_bw() +
    theme(
    plot.title = element_text(face = "bold", size = 14),
    plot.subtitle = element_text(size = 12),
    plot.xys = element_text(size = 10,face = "bold"),
    plot.title.position = "plot",
    plot.caption = element_text(size = 8, face = "bold"),
    plot.background = element_rect(fill = "#F0F0F0")
   )
# Out:
# Warning message in plot_theme(plot):
# "The `plot.xys` theme element is not defined in the element hierarchy."
# plot without title

# %%
currentrbs |>
    filter(position == "RB") |>
    mutate(volume = carries + targets) |>
    group_by(player_display_name) |>
    summarise(volume = sum(volume, na.rm = TRUE)) |>
    arrange(desc(volume)) |>
    slice_head(n = 32) |>
    ggplot(aes(x = reorder(player_display_name, volume), y = volume, label = fantasy_points_ppr_pergame)) +
    geom_bar(stat = "identity", fill = "steelblue") +
    coord_flip() +
    labs(x = "Player", y = "Volume (Carries + Targets)", title = "Top 32 RBs by Volume (2025)") +
    theme_bw()
# Out:
# ERROR while rich displaying an object: Error in `geom_bar()`:
# ! Problem while computing aesthetics.
# ℹ Error occurred in the 1st layer.
# Caused by error:
# ! object 'fantasy_points_ppr_pergame' not found
#
# Traceback:
# 1. sapply(x, f, simplify = simplify)
# 2. lapply(X = X, FUN = FUN, ...)
# 3. FUN(X[[i]], ...)
# 4. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 5. tryCatchList(expr, classes, parentenv, handlers)
# 6. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 7. doTryCatch(return(expr), name, parentenv, handler)
# 8. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 9. repr::mime2repr[[mime]](obj)
# 10. repr_text.default(obj)
# 11. paste(capture.output(print(obj)), collapse = "\n")
# 12. capture.output(print(obj))
# 13. withVisible(...elt(i))
# 14. print(obj)
# 15. `print.ggplot2::ggplot`(obj)
# 16. ggplot_build(x)
# 17. `ggplot_build.ggplot2::ggplot`(x)
# 18. by_layer(function(l, d) l$compute_aesthetics(d, plot), layers,
#   .     data, "computing aesthetics")
# 19. try_fetch(for (i in seq_along(data)) {
#   .     out[[i]] <- f(l = layers[[i]], d = data[[i]])
#   . }, error = function(cnd) {
#   .     cli::cli_abort(c("Problem while {step}.", i = "Error occurred in the {ordinal(i)} layer."),
#   .         call = layers[[i]]$constructor, parent = cnd)
#   . })
# 20. tryCatch(withCallingHandlers(expr, condition = function(cnd) {
#   .     {
#   .         .__handler_frame__. <- TRUE
#   .         .__setup_frame__. <- frame
#   .         if (inherits(cnd, "message")) {
#   .             except <- c("warning", "error")
#   .         }
#   .         else if (inherits(cnd, "warning")) {
#   .             except <- "error"
#   .         }
#   .         else {
#   .             except <- ""
#   .         }
#   .     }
#   .     while (!is_null(cnd)) {
#   .         if (inherits(cnd, "error")) {
#   .             out <- handlers[[1L]](cnd)
#   .             if (!inherits(out, "rlang_zap"))
#   .                 throw(out)
#   .         }
#   .         inherit <- .subset2(.subset2(cnd, "rlang"), "inherit")
#   .         if (is_false(inherit)) {
#   .             return()
#   .         }
#   .         cnd <- .subset2(cnd, "parent")
#   .     }
#   . }), stackOverflowError = handlers[[1L]])
# 21. tryCatchList(expr, classes, parentenv, handlers)
# 22. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 23. doTryCatch(return(expr), name, parentenv, handler)
# 24. withCallingHandlers(expr, condition = function(cnd) {
#   .     {
#   .         .__handler_frame__. <- TRUE
#   .         .__setup_frame__. <- frame
#   .         if (inherits(cnd, "message")) {
#   .             except <- c("warning", "error")
#   .         }
#   .         else if (inherits(cnd, "warning")) {
#   .             except <- "error"
#   .         }
#   .         else {
#   .             except <- ""
#   .         }
#   .     }
#   .     while (!is_null(cnd)) {
#   .         if (inherits(cnd, "error")) {
#   .             out <- handlers[[1L]](cnd)
#   .             if (!inherits(out, "rlang_zap"))
#   .                 throw(out)
#   .         }
#   .         inherit <- .subset2(.subset2(cnd, "rlang"), "inherit")
#   .         if (is_false(inherit)) {
#   .             return()
#   .         }
#   .         cnd <- .subset2(cnd, "parent")
#   .     }
#   . })
# 25. f(l = layers[[i]], d = data[[i]])
# 26. l$compute_aesthetics(d, plot)
# 27. compute_aesthetics(..., self = self)
# 28. eval_aesthetics(aesthetics, data)
# 29. lapply(aesthetics, eval_tidy, data = data, env = env)
# 30. FUN(X[[i]], ...)
# 31. .handleSimpleError(function (cnd)
#   . {
#   .     {
#   .         .__handler_frame__. <- TRUE
#   .         .__setup_frame__. <- frame
#   .         if (inherits(cnd, "message")) {
#   .             except <- c("warning", "error")
#   .         }
#   .         else if (inherits(cnd, "warning")) {
#   .             except <- "error"
#   .         }
#   .         else {
#   .             except <- ""
#   .         }
#   .     }
#   .     while (!is_null(cnd)) {
#   .         if (inherits(cnd, "error")) {
#   .             out <- handlers[[1L]](cnd)
#   .             if (!inherits(out, "rlang_zap"))
#   .                 throw(out)
#   .         }
#   .         inherit <- .subset2(.subset2(cnd, "rlang"), "inherit")
#   .         if (is_false(inherit)) {
#   .             return()
#   .         }
#   .         cnd <- .subset2(cnd, "parent")
#   .     }
#   . }, "object 'fantasy_points_ppr_pergame' not found", base::quote(NULL))
# 32. h(simpleError(msg, call))
# 33. handlers[[1L]](cnd)
# 34. cli::cli_abort(c("Problem while {step}.", i = "Error occurred in the {ordinal(i)} layer."),
#   .     call = layers[[i]]$constructor, parent = cnd)
# 35. rlang::abort(message, ..., call = call, use_cli_format = TRUE,
#   .     .frame = .frame)
# 36. signal_abort(cnd, .file)
