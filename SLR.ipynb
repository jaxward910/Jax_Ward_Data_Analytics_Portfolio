# %%
library(nflfastR)
library(tidyverse)
library(nflplotR)
library(nflreadr)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.2
# ✔ ggplot2   4.0.0     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.1.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: 'nflreadr'
#
#
# The following objects are masked from 'package:nflfastR':
#
#     load_pbp, load_player_stats

# %%
ngs <- load_nextgen_stats(2020:2025)
pbp <- load_pbp(2020:2025)

# %%
ngs[ngs$player_display_name == "Bo Nix",]
# Out:
#    season season_type week player_display_name player_position team_abbr
# 1  2024   REG          0   Bo Nix              QB              DEN
# 2  2024   REG          1   Bo Nix              QB              DEN
# 3  2024   REG          2   Bo Nix              QB              DEN
# 4  2024   REG          3   Bo Nix              QB              DEN
# 5  2024   REG          4   Bo Nix              QB              DEN
# 6  2024   REG          5   Bo Nix              QB              DEN
# 7  2024   REG          6   Bo Nix              QB              DEN
# 8  2024   REG          7   Bo Nix              QB              DEN
# 9  2024   REG          8   Bo Nix              QB              DEN
# 10 2024   REG          9   Bo Nix              QB              DEN
# 11 2024   REG         10   Bo Nix              QB              DEN
# 12 2024   REG         11   Bo Nix              QB              DEN
# 13 2024   REG         12   Bo Nix              QB              DEN
# 14 2024   REG         13   Bo Nix              QB              DEN
# 15 2024   REG         15   Bo Nix              QB              DEN
# 16 2024   REG         16   Bo Nix              QB              DEN
# 17 2024   REG         17   Bo Nix              QB              DEN
# 18 2024   REG         18   Bo Nix              QB              DEN
# 19 2024   POST        19   Bo Nix              QB              DEN
# 20 2025   REG          0   Bo Nix              QB              DEN
# 21 2025   REG          1   Bo Nix              QB              DEN
# 22 2025   REG          2   Bo Nix              QB              DEN
# 23 2025   REG          3   Bo Nix              QB              DEN
#    avg_time_to_throw avg_completed_air_yards avg_intended_air_yards
# 1  2.906322          4.495798                 7.386929
# 2  2.842262          2.500385                 6.108333
# 3  2.792714          5.628000                 9.272647
# 4  2.573833          4.642000                 6.865882
# 5  3.004280          2.665000                 8.909200
# 6  2.834154          3.257895                 5.713462
# 7  3.778545          8.514737                10.710000
# 8  3.344000          3.270000                 6.617600
# 9  2.979405          6.434643                10.711111
# 10 3.520273          6.511579                 8.916563
# 11 2.644900          4.322727                 7.222143
# 12 2.839879          3.351429                 3.635000
# 13 2.677405          6.310000                 7.288974
# 14 2.898914          7.366111                12.455484
# 15 2.684364          1.244000                 5.582813
# 16 2.783250          1.132069                 3.333846
# 17 2.595839          5.402500                 7.589032
# 18 2.793138          4.549231                 5.246897
# 19 2.967727          8.571538                11.344545
# 20 2.752063          3.755574                 6.718444
# 21 2.827250          3.000800                 6.010541
# 22 2.651333          3.954091                 4.930333
# 23 2.752640          4.791429                10.189565
#    avg_air_yards_differential ⋯ completion_percentage
# 1  -2.8911308                 ⋯ 66.31393
# 2  -3.6079487                 ⋯ 61.90476
# 3  -3.6446471                 ⋯ 57.14286
# 4  -2.2238824                 ⋯ 69.44444
# 5  -6.2442000                 ⋯ 48.00000
# 6  -2.4555668                 ⋯ 70.37037
# 7  -2.1952632                 ⋯ 57.57576
# 8  -3.3476000                 ⋯ 61.53846
# 9  -4.2764683                 ⋯ 75.67568
# 10 -2.4049836                 ⋯ 57.57576
# 11 -2.8994156                 ⋯ 73.33333
# 12 -0.2835714                 ⋯ 84.84848
# 13 -0.9789744                 ⋯ 59.52381
# 14 -5.0893728                 ⋯ 51.42857
# 15 -4.3388125                 ⋯ 60.60606
# 16 -2.2017772                 ⋯ 72.50000
# 17 -2.1865323                 ⋯ 77.41935
# 18 -0.6976658                 ⋯ 89.65517
# 19 -2.7730070                 ⋯ 59.09091
# 20 -2.9628707                 ⋯ 64.21053
# 21 -3.0097405                 ⋯ 62.50000
# 22 -0.9762424                 ⋯ 73.33333
# 23 -5.3981366                 ⋯ 56.00000
#    expected_completion_percentage completion_percentage_above_expectation
# 1  68.88307                        -2.5691358
# 2  67.52643                        -5.6216667
# 3  66.35314                        -9.2102857
# 4  68.57444                         0.8700000
# 5  65.94480                       -17.9448000
# 6  73.63074                        -3.2603704
# 7  63.65697                        -6.0812121
# 8  74.00308                       -12.4646154
# 9  68.95216                         6.7235135
# 10 64.97061                        -7.3948485
# 11 67.03733                         6.2960000
# 12 74.76242                        10.0860606
# 13 64.98905                        -5.4652381
# 14 58.75543                        -7.3268571
# 15 72.75788                       -12.1518182
# 16 76.73950                        -4.2395000
# 17 70.36968                         7.0496774
# 18 74.36448                        15.2906897
# 19 62.38818                        -3.2972727
# 20 66.95611                        -2.7455789
# 21 63.66600                        -1.1660000
# 22 73.98967                        -0.6563333
# 23 63.78000                        -7.7800000
#    avg_air_distance max_air_distance player_gsis_id player_first_name
# 1  21.31081         68.46401         00-0039732     Bo
# 2  20.25170         41.76618         00-0039732     Bo
# 3  21.24923         68.46401         00-0039732     Bo
# 4  21.41622         38.58233         00-0039732     Bo
# 5  21.88949         48.89427         00-0039732     Bo
# 6  21.03263         62.21115         00-0039732     Bo
# 7  23.69251         60.43433         00-0039732     Bo
# 8  19.70548         36.71859         00-0039732     Bo
# 9  24.08592         61.77777         00-0039732     Bo
# 10 22.64530         49.80490         00-0039732     Bo
# 11 22.24427         46.25545         00-0039732     Bo
# 12 16.75315         30.85360         00-0039732     Bo
# 13 22.03653         53.60026         00-0039732     Bo
# 14 26.01032         59.50228         00-0039732     Bo
# 15 19.97730         56.28293         00-0039732     Bo
# 16 17.64513         55.51837         00-0039732     Bo
# 17 21.92456         66.95446         00-0039732     Bo
# 18 20.25551         54.33450         00-0039732     Bo
# 19 24.55417         53.51479         00-0039732     Bo
# 20 19.75359         56.85472         00-0039732     Bo
# 21 18.68729         43.89078         00-0039732     Bo
# 22 18.59266         48.55453         00-0039732     Bo
# 23 22.98319         56.85472         00-0039732     Bo
#    player_last_name player_jersey_number player_short_name
# 1  Nix              10                   B.Nix
# 2  Nix              10                   B.Nix
# 3  Nix              10                   B.Nix
# 4  Nix              10                   B.Nix
# 5  Nix              10                   B.Nix
# 6  Nix              10                   B.Nix
# 7  Nix              10                   B.Nix
# 8  Nix              10                   B.Nix
# 9  Nix              10                   B.Nix
# 10 Nix              10                   B.Nix
# 11 Nix              10                   B.Nix
# 12 Nix              10                   B.Nix
# 13 Nix              10                   B.Nix
# 14 Nix              10                   B.Nix
# 15 Nix              10                   B.Nix
# 16 Nix              10                   B.Nix
# 17 Nix              10                   B.Nix
# 18 Nix              10                   B.Nix
# 19 Nix              10                   B.Nix
# 20 Nix              10                   B.Nix
# 21 Nix              10                   B.Nix
# 22 Nix              10                   B.Nix
# 23 Nix              10                   B.Nix

# %%
ngs |>
    select(avg_time_to_throw, completion_percentage, avg_completed_air_yards, aggressiveness, avg_air_yards_to_sticks) |>
    cor(use = 'complete.obs' )
# Out:
#                         avg_time_to_throw completion_percentage
# avg_time_to_throw        1.00000000       -0.25273981
# completion_percentage   -0.25273981        1.00000000
# avg_completed_air_yards  0.29115280       -0.07501298
# aggressiveness           0.01031176       -0.28951955
# avg_air_yards_to_sticks  0.29490083       -0.30814615
#                         avg_completed_air_yards aggressiveness
# avg_time_to_throw        0.29115280              0.01031176
# completion_percentage   -0.07501298             -0.28951955
# avg_completed_air_yards  1.00000000              0.16815850
# aggressiveness           0.16815850              1.00000000
# avg_air_yards_to_sticks  0.67723196              0.28678882
#                         avg_air_yards_to_sticks
# avg_time_to_throw        0.2949008
# completion_percentage   -0.3081462
# avg_completed_air_yards  0.6772320
# aggressiveness           0.2867888
# avg_air_yards_to_sticks  1.0000000

# %% [markdown]
# avg_time_to_throw vs completion_percentage = -0.25
#  Slight negative relationship. QBs who hold the ball longer tend to complete a slightly lower percentage of passes. Not a strong effect, but suggests efficiency drops with extra time.
#
# avg_time_to_throw vs avg_completed_air_yards = 0.29
# Small positive relationship. The longer a QB holds the ball, the more yards downfield they tend to complete passes. Makes sense: deeper routes take longer to develop.
#
# avg_time_to_throw vs aggressiveness = 0.01
# Essentially no relationship. Time to throw doesn’t really correlate with whether a QB targets tightly covered receivers.
#
# avg_time_to_throw vs avg_air_yards_to_sticks = 0.29
# Small positive relationship. Longer time to throw is linked with throwing slightly past the first-down marker more often. This fits the idea that extended plays allow for routes beyond the sticks.
#
# Overall Takeaway
#
# Holding the ball longer slightly hurts completion % but is positively associated with deeper throws and passes past the sticks.
#
# Aggressiveness is mostly independent of how long a QB holds the ball.
#
# None of these correlations are super strong (all < |0.3|), so these are tendencies, not hard rules.

# %%
expected_comp_r <- lm(completion_percentage ~ 1 + avg_time_to_throw, data = ngs)

summary(expected_comp_r)
# Out:
# Call:
# lm(formula = completion_percentage ~ 1 + avg_time_to_throw, data = ngs)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -41.746  -5.550   0.097   5.715  37.463
#
# Coefficients:
#                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)        88.8921     1.6370   54.30   <2e-16 ***
# avg_time_to_throw  -8.5659     0.5839  -14.67   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 8.9 on 3154 degrees of freedom
# Multiple R-squared:  0.06388,	Adjusted R-squared:  0.06358
# F-statistic: 215.2 on 1 and 3154 DF,  p-value: < 2.2e-16

# %% [markdown]
# Regression Equation
#
# completion_percentage ​= 88.89−8.56×avg_time_to_throw
#
#
# The intercept (88.89) means that if a QB had an average time to throw of 0 seconds (hypothetical), the model predicts ~88% completion percentage. (Not meaningful in reality, but that’s the baseline reference.)
#
# The slope (-8.56) means that for every additional second a QB holds the ball, their completion percentage decreases by about 8.5 percentage points on average.

# %%
ngs <- ngs |>
    mutate(xcomp = residuals(expected_comp_r))

head(ngs$xcomp)
# Out:
#            1            2            3            4            5            6
#  0.681635524 -1.625681354 -0.005389755  0.039389987 -0.857980971  5.165871420

# %%
xcomp_r <- ngs |>
    group_by(season, player_display_name) |>
    summarize(
        n = n(), 
        xcomp = mean(xcomp)
    ) |>
    arrange(-xcomp) 
    
head(xcomp_r)
# Out:
# `summarise()` has grouped output by 'season'. You can override using the
# `.groups` argument.
#   season player_display_name n  xcomp
# 1 2024   Joe Milton III       1 18.076779
# 2 2024   Marcus Mariota       2 16.277574
# 3 2025   Jared Goff           4 14.917032
# 4 2025   Brock Purdy          2 11.482325
# 5 2024   Jared Goff          19  8.662445
# 6 2025   Jalen Hurts          4  8.120339

# %%
xcomp_r |>
    arrange(xcomp)
# Out:
#     season player_display_name      n  xcomp
# 1   2021   Jake Fromm                2 -25.55594
# 2   2022   Anthony Brown             1 -22.70051
# 3   2023   Blaine Gabbert            1 -19.02555
# 4   2023   Davis Mills               1 -18.98052
# 5   2024   Tim Boyle                 1 -17.64552
# 6   2023   Brett Rypien              1 -17.55060
# 7   2022   Trey Lance                1 -17.26151
# 8   2024   Anthony Richardson       10 -16.67074
# 9   2021   Brandon Allen             1 -16.22439
# 10  2022   Trace McSorley            2 -15.94706
# 11  2023   Jeff Driskel              1 -15.75205
# 12  2023   Brian Hoyer               1 -15.33160
# 13  2022   Malik Willis              2 -14.43446
# 14  2024   Jake Haener               1 -14.08023
# 15  2023   Phillip Walker            2 -14.05674
# 16  2023   P.J. Walker               1 -14.02540
# 17  2024   Bailey Zappe              1 -13.97504
# 18  2024   Dorian Thompson-Robinson  3 -13.82702
# 19  2021   Cam Newton                4 -13.77333
# 20  2023   Dorian Thompson-Robinson  3 -12.47133
# 21  2024   Davis Mills               1 -12.11820
# 22  2023   Trevor Siemian            5 -12.03191
# 23  2020   Ben DiNucci               1 -11.87833
# 24  2020   Tyrod Taylor              1 -11.82473
# 25  2020   Jake Luton                3 -11.67104
# 26  2020   Jeff Driskel              2 -11.44064
# 27  2020   Jalen Hurts               5 -11.31956
# 28  2020   Garrett Gilbert           1 -10.62517
# 29  2023   Anthony Richardson        2 -10.59078
# 30  2023   Jameis Winston            2 -10.42456
# ⋮   ⋮      ⋮                        ⋮  ⋮
# 330 2021   Colt McCoy                3  4.895620
# 331 2023   Kirk Cousins              9  4.911993
# 332 2020   Aaron Rodgers            19  5.123900
# 333 2022   Geno Smith               19  5.163591
# 334 2025   Tyrod Taylor              2  5.231849
# 335 2023   Mason Rudolph             4  5.369533
# 336 2025   Sam Darnold               4  5.369713
# 337 2023   C.J. Beathard             2  5.417573
# 338 2020   Deshaun Watson           17  5.420911
# 339 2025   Justin Fields             2  5.540353
# 340 2020   Taysom Hill               4  5.667384
# 341 2020   Josh Allen               20  5.795757
# 342 2025   Daniel Jones              4  5.966513
# 343 2023   Jake Browning             8  6.005879
# 344 2021   Gardner Minshew           2  6.026414
# 345 2022   Bailey Zappe              4  6.293908
# 346 2024   Baker Mayfield           19  6.429017
# 347 2025   Dak Prescott              4  6.531579
# 348 2024   Geno Smith               18  6.559862
# 349 2024   Lamar Jackson            20  6.976969
# 350 2024   Jalen Hurts              18  7.398981
# 351 2021   Phillip Walker            1  7.693883
# 352 2025   Lamar Jackson             4  7.977356
# 353 2025   Drake Maye                4  8.117055
# 354 2025   Jalen Hurts               4  8.120339
# 355 2024   Jared Goff               19  8.662445
# 356 2025   Brock Purdy               2 11.482325
# 357 2025   Jared Goff                4 14.917032
# 358 2024   Marcus Mariota            2 16.277574
# 359 2024   Joe Milton III            1 18.076779

# %%
plot_data <- xcomp_r |>
    inner_join(ngs, by = c("season", "player_display_name"))

# %%
plot_data_filtered <- plot_data |>
    filter(player_display_name %in% c("Patrick Mahomes", "Bo Nix", "Geno Smith", "Justin Herbert", "Joe Burrow", "Lamar Jackson", "Aaron Rodgers", "Joe Flacco")) |>
    filter(week == 0) |>
    filter(season == 2025)

# %%
plot_data_filtered |>
    select(player_display_name, season, xcomp.x, completion_percentage, avg_time_to_throw)
# Out:
#   player_display_name season xcomp.x   completion_percentage avg_time_to_throw
# 1 Lamar Jackson       2025    7.977356 72.00000              2.889493
# 2 Justin Herbert      2025    3.746664 66.66667              2.932046
# 3 Geno Smith          2025    2.540138 63.20755              3.202238
# 4 Aaron Rodgers       2025   -1.048244 65.11628              2.607744
# 5 Bo Nix              2025   -1.360773 64.21053              2.752063
# 6 Joe Flacco          2025   -3.692781 61.11111              2.829488
# 7 Joe Burrow          2025   -5.624910 58.33333              2.769500
# 8 Patrick Mahomes     2025   -8.519358 59.04762              2.513000

# %%
ngs_plot <- ggplot(plot_data_filtered, aes(x = xcomp.x, y = completion_percentage)) +
  geom_nfl_headshots(aes(player_gsis = player_gsis_id), width = 0.075, vjust = 0.45) +
  labs(
    x = "QB Completion percentage over expected",
    y = "QB Actual Completion percentage",
    caption = "Data: @nflfastR",
    title = "2025 NFL QB completion percentage over expected regressed on average time to throw",
  ) +
  theme_minimal() +
  theme(
    plot.title = element_text(face = "bold", size = 10),
    plot.title.position = "plot",
    plot.background = element_rect(fill = "#F0F0F0")
  ) +
  xlim(-10, 10) +
  ylim(50, 100) 

ggsave("ngs_xcomp.png", plot = ngs_plot, width = 16, height = 12, units = "in")

print(ngs_plot)
# Out:
# plot without title

# %% [markdown]
# Conclusion
#
# Looking at the above chart we can see our 8 QBs from the two divisions we have been following. One of the most interesting insights we can see is that Patrick Mahomes despite having the shortest time to throw, has the lowest completion percentage over expected. Why is this the case, since our model predicts that a decrease in time to throw should have a positive relationship with completion percentage? Probably a lot of different reasons, to start with, time to throw is not  strongly correlated to completion percentage and there are a lot of different things that affect completion percentage than just time to throw. Completion percentage also doesn't factor in wide reciever drops or deflected passes both of which the Chiefs offense have struggled with. Other factors that might have an impact on completion percentage like depth of target, wide reciever seperation, and pressure rate are also not accounted for.
#
# Another interesting case is Lamar Jackson. Jackson at the very top right corner of the chart has the highest completion percentage and the highest completion percentage over expected. Holding the ball for almost three seconds and still completing about 71 perecent of his passes. Based on the above equation we would expect that number to be closer to about 64 percent. I would imagine this is due to two factors. Lamar jackson has not thrown the ball as much this season and has only played 3 games so the sample size is relatively small and on the other hand Lamar is one of the best QBs at throwing on the move and extending the play naturally making his time to throw higher than other QBs.
#
# Other insights into Bo Nix and Joe Flacco might indicate a need to speed up the internal clock and work on anticipation as they had higher time to throws and negative completion percentages over expected.
#
# The Last case I want to highlight is Geno Smith. Smith despite holding the ball for 3.2 seconds on average has a positive completion percentage over expected and a very respectable 63 percent actual completion percentage. This shows Geno Smith accuracy, poise in the pocket, and maybe indicates low aggressiveness. Smith threw 3 interceptions in week 2 and attempted 43 passes and still has a postive completion percentage over expected. I think we can expect Smith going forward to regress positively and bring the completion percentage even higher as he plays more games and his sample size increases.
